# %% [markdown]
# # 스크립트 프로그래밍 Assignment 5

# %% [markdown]
# |분반|01|
# |---|---|
# |교수|한연희 교수님|
# |학과|컴퓨터공학부|
# |학년|3학년|
# |학번|2012136116|
# |이름|정재우(wodndb@koreatech.ac.kr)
# |제출일|2014년 12월 12일|

# %% [markdown]
# ### [1번 문제] 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# - 클래스와 모듈은 이름 공간을 지원하는 단위라는 점에서 공통점이 있다. 이 두 단위의 차이점은 지원하는 이름 공간 영역인데, 모듈은 파일 단위로 이름을 구성하는 반면, 클래스는 클래스 영역 내에 이름 공간을 구성한다.

# %% [markdown]
# ### [2번 문제] 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# - 조금 언어학적인 측면에서 분석하면 다형성(Polymorphism)의 'Poly'는 많은(many, much)를 의미하고, 'Morphe'는 형식, 형태를 의미한다. 직관적으로 다양한 형태를 뜻하게 되는데, 컴퓨터 과학에서는 단일한 인터페이스에 다양한 자료 개체를 지원하는 것을 의미한다. 파이썬에서 클래스가 지니는 다형성(Polymorphism)이란 상속 관계 내의 다른 클래스들의 인스턴스들이 같은 멤버 함수 호출에 대해 각각 다르게 반응하도록 하는 기능이다. 연산자 오버로딩도 다형성을 지원하는 중요한 기술이다. 다형성의 장점으로는 작성 코드량을 줄여 프로그래머의 생산성을 높여주며, 다양한 객체에게 유사한 작업을 직관적으로 손쉽게 시행시킬 수 있으며, 가독성을 높여준다는 점 등이 있다.

# %%
#/usr/local/bin/python
# coding: utf-8

class Poketmon:			#Parent Class
	def cry(self):
		print 'this is Poketmon class'

class Pikachu(Poketmon):	#Child Class 1
	def cry(self):
		print 'Pit-Ka-Chu!!!!'

class Pairi(Poketmon):		#Child Class 2
	def cry(self):
		print 'Pa----e---ri!'

class Butterfree(Poketmon):	#Child Class 3
	def cry(self):
		print 'Bba-Tta!'

for each in (Pikachu(), Pairi(), Butterfree()):
	each.cry()
# Out:
# Pit-Ka-Chu!!!!
# Pa----e---ri!
# Bba-Tta!

# %% [markdown]
# ### [3번 문제] 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %% [markdown]
#   - 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#     - count: Counter 인스턴스가 지니는 초기 정수 값
#     - step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
#     > \>\>\> c = Counter(10) <br/>
#     > \>\>\> d = Counter(10, 2) <br/>
#
#   - 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 \_\_str\_\_() 메소드를 구현하시오.
#     > \>\>\> print c  <br/>
#     > [Count (step: 1)] 10 <br/>
#     > \>\>\> print d  <br/>
#     > [Count (step: 2)] 10 <br/>
#
#   - 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 구현하시오.
#     > \>\>\> c.incr()  <br/>
#     > \>\>\> d.incr()  <br/>
#     > \>\>\> print c  <br/>
#     > [Count (step: 1)] 11 <br/>
#     > \>\>\> print d  <br/>
#     > [Count (step: 2)] 12 <br/>
#
#   - 요구사항 4. \_\_call\_\_() 메소드를 추가하여 인스턴스 객체를 직접 호출할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때의 동작방식은 incr() 메소드를 호출하였을 때와 동일하다.
#     > \>\>\> c()  <br/>
#     > \>\>\> d()  <br/>
#     > \>\>\> print c  <br/>
#     > [Count (step: 1)] 12 <br/>
#     > \>\>\> print d  <br/>
#     > [Count (step: 2)] 14 <br/>
#
#   - 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 관련 메소드를 추가하시오.
#     > \>\>\> c = c + 5  <br/>
#     > \>\>\> d = d - 5  <br/>
#     > \>\>\> print c  <br/>
#     > [Count (step: 1)] 17 <br/>
#     > \>\>\> print d  <br/>
#     > [Count (step: 2)] 9 <br/>
#
#   - 요구사항 6. 다음과 같은 관계연산 (+, -)이 수행될 수 있도록 \_\_cmp\_\_() 메소드를 추가하시오.
#     > \>\>\> print c > 10  <br/>
#     > True <br/>
#     > \>\>\> print d > 10 <br/>
#     > False <br/>
#     > \>\>\> print c < 10  <br/>
#     > False <br/>
#     > \>\>\> print d < 10 <br/>
#     > True <br/>
#     > \>\>\> print c == 17  <br/>
#     > True <br/>
#     > \>\>\> print d != 9 <br/>
#     > False <br/>

# %%
class Counter:
	def __init__(self, count, step = 1):
		self.count = count
		self.step = step
	def __str__(self):
		return '[Count (step: ' + str(self.step) + ')] ' + str(self.count)
	def __call__(self):
		self.count = self.count + self.step
	def __add__(self, other):
		self.count = self.count + other
		return self
	def __sub__(self, other):
		self.count = self.count - other
		return self
	def __cmp__(self, other):
		return self.count - other
	def incr(self):
		self.count = self.count + self.step

# Requirement 1
c = Counter(10)
d = Counter(10, 2)

# Requirement 2
print c
print d

# Requirement 3
c.incr()
d.incr()
print c
print d

# Requirement 4
c()
d()
print c
print d

# Requirement 5
c = c + 5
d = d - 5
print c
print d

# Requirement 6
print c > 10
print d > 10
print c < 10
print d < 10
print c == 17
print d != 9
# Out:
# [Count (step: 1)] 10
# [Count (step: 2)] 10
# [Count (step: 1)] 11
# [Count (step: 2)] 12
# [Count (step: 1)] 12
# [Count (step: 2)] 14
# [Count (step: 1)] 17
# [Count (step: 2)] 9
# True
# False
# False
# True
# True
# False

# %% [markdown]
# - 요구 사항이 기본적인 기능을 구현하는 것이기 때문에 코드로 간단하게 구현할 수 있었다. 특이 사항이 있다고 하면 self를 적극 활용하였다는 점이다.

# %% [markdown]
# ### - [4번 문제] 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 \_\_init\_\_(), \_\_str()\_\_(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.

# %% [markdown]
#   - MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# - [설명]
#
#     - 클래스 MySet은 리스트 클래스를 상속받은 클래스다. 크게 __init__()이라는 클래스 생성자, __str__()이라는 표준 출력할 때 호출되는 함수, 그리고 MySet 클래스가 가지고 있는 멤버 변수인 리스트의 중복을 제거하는 eliminate_duplicate(l)함수가 있다.
#     - 먼저 __init__()이라는 생성자 함수부터 살펴보면, 인자로 받은 리스트를 멤버변수 리스트에 추가한 뒤, 추가된 리스트의 속성들 중 중복되는 속성을 제거하는 eliminamte_duplicate함수를 재귀호출한다. 일반적인 리스트에서 중복되는 속성이 없는 리스트, 즉 집합(Set) 자료를 생성하게 된다.
#     - __str__() 함수는 슬라이싱을 이용하여 멤버변수인 리스트(사실상 집합)의 내용을 출력하는 간단한 내용의 코드로 이루어져 있다.
#     - MySet 클래스의 가장 핵심적인 함수인 eliminate_duplicate() 함수도 별 내용은 없다. 비어있는 리스트 자료에 중복된 속성이 존재할 지도 모르는 멤버 변수 리스트를 하나씩 넣는데, 중복된 속성 값이 들어가지 않도록 따져가며 넣는다. 그리고 기존의 멤버변수 리스트의 내용을 비운 뒤, 새로 만든 리스트로 빈 자리를 채운다. 공간복잡도는 둘째 치고, 직관적으로 이해하기에는 쉬운 코드가 아닐 수 없다.

# %% [markdown]
# ### [5번 문제] 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)

# %% [markdown]
#   - 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#     > \>\>\> s = s | t  <br/>
#     > \>\>\> print s  <br/>
#     > MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9} <br/>
#
#   - 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#     > \>\>\> s = MySet([1, 2, 3])  <br/>
#     > \>\>\> t = MySet([3, 4, 5])  <br/>
#     > \>\>\> s = s & t  <br/>
#     > \>\>\> print s  <br/>
#     > MySet: {3} <br/>
#
#   - 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#     > \>\>\> s = MySet([1, 2, 3])  <br/>
#     > \>\>\> t = MySet([3, 4, 5])  <br/>
#     > \>\>\> s = s - t  <br/>
#     > \>\>\> print s  <br/>
#     > MySet: {1, 2} <br/>

# %%
#/usr/local/bin/python
# coding: utf-8

class MySet(list):
	def __init__(self, l):
		for e in l:
			self.append(e)
		MySet.eliminate_duplicate(self)

	def __str__(self):
		result = "MySet: {"
		for e in self:
			result = result + str(e) + ", "
		result = result[0:len(result) - 2] + "}"
		return result
	
	def __or__(self, otherList):
		for e in otherList:
			self.append(e)
			MySet.eliminate_duplicate(self)
		return self

	def __and__(self, otherList):
		s = []
		for e in otherList:
			if e in self:
				s.append(e)
		return MySet(s)
	
	def __sub__(self, otherList):
		s = []
		for e in self:
			if e not in otherList:
				s.append(e)
		return MySet(s)	

	@staticmethod
	def eliminate_duplicate(l):
		s = []
		for e in l:
			if e not in s:
				s.append(e)
		l[:] = []
		for e in s:
			l.append(e)

if __name__ == "__main__":
	s = MySet([1, 2, 2, 3])
	print s
	t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
	print t
	
	# Requirement 1
	s = s | t
	print s
	
	# Requirement 2
	s = MySet([1, 2, 3])
	t = MySet([3, 4, 5])
	s = s & t
	print s
	
	# RequireMent 3
	s = MySet([1, 2, 3])
	t = MySet([3, 4, 5])
	s = s - t
	print s
# Out:
# MySet: {1, 2, 3}
# MySet: {2, 3, 4, 5, 6, 7, 8, 9}
# MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# MySet: {3}
# MySet: {1, 2}

# %% [markdown]
# - [설명]
#     - __or__, __and__, __sub__에 대한 오버로딩을 하였다. 각각 원소의 중복 여부에 따라 원소를 구성하기 때문에 in과 not in 키워드를 중점적으로 사용하여 기능을 구현하였다.

# %% [markdown]
# ### [6번 문제] 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %% [markdown]
# -
#
#     > \>\>\> s = MySet([1, 2, 3, 4, 5, 6])  <br/>
#     > \>\>\> print len(s)  <br/>
#     > 6 <br/>
#     > \>\>\> print bool(s)  <br/>
#     > True <br/>
#     > \>\>\> print 2 in s  <br/>
#     > True <br/>

# %%
#/usr/local/bin/python
# coding: utf-8

class MySet(list):
	def __init__(self, l):
		for e in l:
			self.append(e)
		MySet.eliminate_duplicate(self)

	def __str__(self):
		result = "MySet: {"
		for e in self:
			result = result + str(e) + ", "
		result = result[0:len(result) - 2] + "}"
		return result
	
	def __or__(self, otherList):
		for e in otherList:
			self.append(e)
			MySet.eliminate_duplicate(self)
		return self

	def __and__(self, otherList):
		s = []
		for e in otherList:
			if e in self:
				s.append(e)
		return MySet(s)
	
	def __sub__(self, otherList):
		s = []
		for e in self:
			if e not in otherList:
				s.append(e)
		return MySet(s)	

	@staticmethod
	def eliminate_duplicate(l):
		s = []
		for e in l:
			if e not in s:
				s.append(e)
		l[:] = []
		for e in s:
			l.append(e)

if __name__ == "__main__":
	s = MySet([1, 2, 3, 4, 5, 6])
	print len(s)
	print bool(s)
	print 2 in s
# Out:
# 6
# True
# True

# %% [markdown]
# - [설명]
#     - 해당 클래스는 list를 상속받았기 때문에, 해당 클래스에서 정의되지 않은 메소드는 부모 클래스의 이름 공간을 참조하게 된다. 따라서 에러가 발생하지 않고 list에 정의된 메소드인 len(), bool() 내장함수와 in키워드 사용 예제가 잘 작동하는 것이다.

# %% [markdown]
# ### [7번 문제] 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3과 Assignment 4를 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.

# %% [markdown]
#   - 1) 새로운 클래스 WebWordsFrequency를 정의하시오.
#   - 2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#     > \>\>\> w1 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') <br/>
#     > \>\>\> w2 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com') <br/>
#     > \>\>\> w3 = WebWordsFrequency() <br/>
#   - 3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#     - 반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#
#     > \>\>\> w1.addUrl('http://cse.koreatech.ac.kr')<br/>
#     > \>\>\> w3.addUrl('http://www.koreatech.ac.kr')<br/>
#   - 4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#     - 반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#
#     > \>\>\> w1.removeUrl('http://www.daum.net')<br/>
#     > \>\>\> w2.removeUrl('http://www.naver.com')<br/>
#   - 5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#     > \>\>\> w1.listUrls()<br/>
#     > http://www.naver.com <br/>
#     > http://www.google.co.kr <br/>
#     > http://cse/koreatech.ac.kr <br/>
#   - 6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#     - 만약 등록된 URL이 없다면 공백 사전을 반환
#
#     > \>\>\> w1.getWordsFrequency() <br/>
#     > {'다음': 8, '안녕': 12, 'world': 2, '우리': 11, 'hello': 1, 'python': 1}
#   - 7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#     - 최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#     - 만약 등록된 URL이 없다면 None을 반환
#
#     > \>\>\> w1.getMaxFreqencyWords() <br/>
#     > 우리 <br/>
#     > \>\>\> w2.getMaxFreqencyWords() <br/>
#     > 다음에 <br/>
#     > 안녕
#   - 8) Assignment 4에서 요구했던 파일로 저장하는 코드는 모두 삭제하시오.

# %%
#!/usr/local/bin/python
# coding: utf-8
import sys, os, urllib, string

def printDictForKorKey(d):
	if len(d) == 0:
		print {}
	else:
		print '{',
		for key, value in d.items():
			print '\'' + key + '\': ', value, ',',
		print '}'


# Url을 파싱하여 단어 및 단어 개수를 사전 형태로 반환하는 함수다.
def parsingUrl(url):
	s = urllib.urlopen(url).read()
	
	n = 0
	pivot = 0
	while(n < len(s)):
		if(s[n] == "<" and s[n + 1 : n + 7].lower() == "script"):
			pivot = n
			while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 8].lower() != "script"):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+9:]
	
		elif(s[n] == "<" and s[n + 1 : n + 6].lower() == "style"):
			pivot = n
			while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 7].lower() != "style"):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+8:]
	
		elif(s[n] == '<'):
			pivot = n
			while(s[pivot] != '>'):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+1:]
		elif(s[n] == '\n' or s[n] == '\t'):
			s = s[0:n] + ' ' + s[n+1:]
		elif(s[n] in string.punctuation):
			s = s[0:n] + s[n+1:]
		else:
			n += 1

	s2 = s.split()
	s3 = ' '.join(s2)
	n = 0
	D = {}
	while(n < len(s2)):
		if(s2[n] in D.keys()):
			D[s2[n]] += 1
		else:
			D[s2[n]] = 1
		n += 1
	
	return D
	

# 웹사이트 상의 단어 빈도에 대한 정보를 다루는 클래스다.
class WebWordsFrequency:

	# 생성자
	def __init__(self, *urls):
		self.urlList = list(urls)

	# Url 추가
	def addUrl(self, strUrl):
		self.urlList.append(strUrl)

	# Url 삭제
	def removeUrl(self, strUrl):
		self.urlList.remove(strUrl)

	# Url 목록 출력
	def listUrls(self):
		for e in self.urlList:
			print e

	# 저장된 웹사이트 url에 기반한 단어 빈도 사전 출력
	def getWordsFrequency(self):
		totalDict = {}
	
		for urls in self.urlList:
			D = parsingUrl(urls)
			keys = totalDict.keys()
			for key, value in D.items():
				if(key in keys):
					totalDict[key] += value
				else:
					totalDict[key] = value
		return totalDict

	# 최다 빈도 출현 단어 출력
	def getMaxFrequencyWords(self):
		if len(self.urlList) == 0:
			return None
		else:
			maxValues = 0
			maxKeys = []
			maxUrls = ' '
			
			totalDict = {}
	
			for urls in self.urlList:
				D = parsingUrl(urls)
				keys = totalDict.keys()
				for key, value in D.items():
					if(key in keys):
						totalDict[key] += value
					else:
						totalDict[key] = value
		
			for key, value in totalDict.items():
				if(maxValues < value):
					maxValues = value
					maxKeys = [key]
				elif(maxValues == value):
					maxKeys.append(key)
			
			print "<Maximum Frequency Word List>"
			print " - Frequency : ", maxValues
			for k in maxKeys:
				print k
			print

if __name__ == "__main__":
	# Requirement 1
	w1 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr')
	w2 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com')
	w3 = WebWordsFrequency()

	# Requirement 2
	w1.addUrl('http://cse.koreatech.ac.kr')
	w3.addUrl('http://www.koreatech.ac.kr')

	# Requirement 3
	w1.removeUrl('http://www.daum.net')
	w2.removeUrl('http://www.naver.com')

	# Requirement 4
	w1.listUrls()

	# Requirement 5
	printDictForKorKey(w1.getWordsFrequency())

	# Requirement 6
	w1.getMaxFrequencyWords()
	w2.getMaxFrequencyWords()
# Out:
# http://www.naver.com
# http://www.google.co.kr
# http://cse.koreatech.ac.kr
# {
# ...

# %% [markdown]
# - [설명]
#     - 대부분의 소스 코드는 이전 과제에서 참조하였으나, 문제가 요구한 대로 파일 입출력에 대한 기능을 전부 지워야 했고, 본 문제에 알맞게 함수를 개편해야 했다.
#     - 생성자에서는 가변인수로 받은 url 주소값들을 리스트로 변환하여 저장한다.
#     - 따라서 url을 추가하고 삭제하는 멤버 메소드는 리스트 내장 함수를 활용하여 기능을 구현하였다.
#     - 사전을 구성하는 부분은 3번째 과제 마지막 문제 거의 그대로 사용하게 되었다. 약간 달라진 점이 있다면 url 단어 파싱 기능을 메소드의 형태로 구현하되, url을 입력받으면 사전을 반환하도록 만들었다. 이러한 구조는 이전 과제의 파일 입출력을 위해 재구성한 단어 파싱 함수와 거의 유사하다고 할 수 있으나, 사전을 반환하느냐, 아님 파일을 생성하느냐라는 점에서 차이점이 있다.
#     - 사전에서 최대 빈도를 찾는 기능은 이전 과제 소스 코드와 거의 동일하다. 흔한 순차 탐색 최대값 알고리즘을 이용하여 최대 빈도값을 알아내는데, 탐색을 하면서 최대 빈도 값과 같은 단어가 존재하면 최대 빈도수를 지닌 단어들을 저장하는 리스트에 이를 추가한다. 더 큰 빈도수의 단어가 발견되면 이전의 단어 리스트 대신에 새로운 단어 리스트로 바꾼다.
#     - 사전을 print로 표준 출력하고자 하였으나, 한글이 깨지는 현상이 발생하여 따로 사전 객체의 내용을 출력하는 함수를 만들었다.

# %% [markdown]
# ### [8번 문제] 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.

# %% [markdown]
# -
#     - 리스트 내의 각 원소는 단어와 빈도를 쌍으로 지니는 튜플이다.
#
#     > \>\>\> w4 = OrderedWebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') <br/>
#     > \>\>\> w4.getWordsFrequency() <br/>
#     > [('안녕', 12), ('우리', 11), ('다음', 8), ('world', 2), ('hello', 1), ('python', 1)]

# %%
#!/usr/local/bin/python
# coding: utf-8
import sys, os, urllib, string

def dictListCmp(dl1, dl2):
	return cmp(dl2[1], dl1[1])

def printDictForKorKey(d):
	if len(d) == 0:
		print '{}'
	else:
		print '{',
		for key, value in d.items():
			print '\'' + key + '\': ', value, ',',
		print '}'

def printDictListForKorKey(dl):
	if len(dl) == 0:
		print '[]'
	else:
		print '[',
		for tempDl in dl:
			print '(\'' + tempDl[0] + '\',' + str(tempDl[1]) +')',
		print ']'

# Url을 파싱하여 단어 및 단어 개수를 사전 형태로 반환하는 함수다.
def parsingUrl(url):
	s = urllib.urlopen(url).read()
	
	n = 0
	pivot = 0
	while(n < len(s)):
		if(s[n] == "<" and s[n + 1 : n + 7].lower() == "script"):
			pivot = n
			while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 8].lower() != "script"):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+9:]
	
		elif(s[n] == "<" and s[n + 1 : n + 6].lower() == "style"):
			pivot = n
			while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 7].lower() != "style"):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+8:]
	
		elif(s[n] == '<'):
			pivot = n
			while(s[pivot] != '>'):
				pivot += 1
			s = s[0:n] + ' ' + s[pivot+1:]
		elif(s[n] == '\n' or s[n] == '\t'):
			s = s[0:n] + ' ' + s[n+1:]
		elif(s[n] in string.punctuation):
			s = s[0:n] + s[n+1:]
		else:
			n += 1

	s2 = s.split()
	s3 = ' '.join(s2)
	n = 0
	D = {}
	while(n < len(s2)):
		if(s2[n] in D.keys()):
			D[s2[n]] += 1
		else:
			D[s2[n]] = 1
		n += 1
	
	return D
	

# 웹사이트 상의 단어 빈도에 대한 정보를 다루는 클래스다.
class WebWordsFrequency:

	# 생성자
	def __init__(self, *urls):
		self.urlList = list(urls)

	# Url 추가
	def addUrl(self, strUrl):
		self.urlList.append(strUrl)

	# Url 삭제
	def removeUrl(self, strUrl):
		self.urlList.remove(strUrl)

	# Url 목록 출력
	def listUrls(self):
		for e in self.urlList:
			print e

	# 저장된 웹사이트 url에 기반한 단어 빈도 사전 출력
	def getWordsFrequency(self):
		totalDict = {}
	
		for urls in self.urlList:
			D = parsingUrl(urls)
			keys = totalDict.keys()
			for key, value in D.items():
				if(key in keys):
					totalDict[key] += value
				else:
					totalDict[key] = value
		return totalDict

	# 최다 빈도 출현 단어 출력
	def getMaxFrequencyWords(self):
		if len(self.urlList) == 0:
			return None
		else:
			maxValues = 0
			maxKeys = []
			maxUrls = ' '
			
			totalDict = {}
	
			for urls in self.urlList:
				D = parsingUrl(urls)
				keys = totalDict.keys()
				for key, value in D.items():
					if(key in keys):
						totalDict[key] += value
					else:
						totalDict[key] = value
		
			for key, value in totalDict.items():
				if(maxValues < value):
					maxValues = value
					maxKeys = [key]
				elif(maxValues == value):
					maxKeys.append(key)
			
			print "<Maximum Frequency Word List>"
			print " - Frequency : ", maxValues
			for k in maxKeys:
				print k
			print

class OrderedWebWordsFrequency(WebWordsFrequency):
	def getWordsFrequency(self):
		totalDict = {}
		totalDictList = []	

		for urls in self.urlList:
			D = parsingUrl(urls)
			keys = totalDict.keys()
			for key, value in D.items():
				if(key in keys):
					totalDict[key] += value
				else:
					totalDict[key] = value

		for key, value in totalDict.items():
			totalDictList.append((key, value))
			totalDictList.sort(dictListCmp)

		return totalDictList
		

if __name__ == "__main__":
	w4 = OrderedWebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr')
	printDictListForKorKey(w4.getWordsFrequency())
# Out:
# [ ('상승',26) ('바로',23) ('입니다',22) ('제목',22) ('링크를',22) ('내용을',22) ('확인하시려면',22) ('전',22) ('눌러주세요',22) ('가져오기',22) ('페이지',15) ('네이버',15) ('현재',12) ('바로가기',12) ('다음',11) ('검색어',11) ('자동완성',10) ('탭',10) ('이전',10) ('오늘의',9) ('서비스',9) ('정보',8) ('나눔글꼴',8) ('내',8) ('로그인',8) ('닫기',7) ('책',7) ('도움말',7) ('영화',7) ('끄기',7) ('총',7) ('스포츠',7) ('카페',6) ('검색어저장',6) ('쇼핑',6) ('블로그',6) ('켜기',5) ('게임',5) ('지도',5) ('뮤직',5) ('사전',5) ('검색',5) ('보기',5) ('및',5) ('기능이',5) ('신고',4) ('홈',4) ('부동산',4) ('추천',4) ('txt',4) ('질문',4) ('뉴스',4) ('개인정보취급방침',4) ('1',4) ('증권',4) ('신규진입',4) ('날씨',4) ('대한항공',4) ('1위',4) ('3위',4) ('지역',4) ('광고',4) ('답변',4) ('신문',4) ('2위',4) ('설정',4) ('4',4) ('설치',4) ('삭제',4) ('있습니다',4) ('레이어',4) ('안내',4) ('앱',3) ('다음앱',3) ('연예',3) ('라이프',3) ('96',3) ('8위',3) ('7위',3) ('스페셜',3) ('실시간',3) ('개인',3) ('상품',3) ('6위',3) ('미즈넷',3) ('웹툰',3) ('copy',3) ('기록',3) ('이승기',3) ('2014',3) ('전체',3) ('링크모음',3) ('사무장',3) ('원',3) ('4위',3) ('오늘',3) ('8',3) ('사이트',3) ('9위',3) ('해',3) ('팁',3) ('9',3) ('더보기',3) ('아고
# ...

# %% [markdown]
# - [설명]
#     - 예전 과제를 통해 구현해본 기능이라 어렵지 않게 문제를 해결할 수 있었다.
#     - 여러 url 주소에서 가져온 단어 사전을 하나로 합친 뒤, 튜플을 원소로 갖는 리스트로 변환하였다.
#     - 비교 함수를 따로 만들어 value 값을 기준으로 단어 빈도수 비교가 이루어지도록 하였다.
#     - 이전 문제와 마찬가지로 print로는 기존 사전 객체의 한글 출력 문제가 있어 따로 출력 함수를 만들었다.

# %% [markdown]
# ### 소감

# %% [markdown]
# 스크립트 프로그래밍을 1학기 동안 수강하면서 많은 것을 배웠는데, 그 중에서도 단어를 파싱하는 부분이 가장 재밌었던 것 같다. 그리고 그 단어를 활용하는 것도 재미있었다. 전자사전 자료를 파싱할 기회가 있어 파이썬으로 단어 파싱한 것을 활용하여 전자사전의 자료를 sql문으로 변환, 오라클 데이터베이스에 파퓰레이션 하는 작업을 진행했을 때 많은 도움이 되었다. 수작업으로 1000개로 힘들었을 단어 수집을 몇 십만개를 한꺼번에 했을 때, 컴퓨터의 자원을 어떻게 활용하느냐에 따라 굉장한 힘을 발휘한다는 점을 느낄 수 있었다.
# 아쉬운 점은 시스템 프로그래밍을 같이 수강하면서 셸 스크립트와 굉장히 헷갈리게 된다는 점이다. 비슷한 종류의 언어를 동시에 공부하는 것이 굉장히 비효율적이고 도움이 되지 않는다는 것을 알 수 있었다.
#
# 파이썬을 통해 프로그래밍에 대한 패러다임이 많이 바뀌게 되었다. 처음부터 C, C++에 익숙해져 있었기 때문에 객체보다는 절차적, 함수적 프로그래밍에 익숙해져 있었다. 하지만 파이썬은 철저하게 객체지향적이기 때문에 프로그래밍을 하면서 머리속으로 그리는 알고리즘이나 프로그램의 구성도, 생각의 흐름이나 방식이 절차 지향에서 객체 지향으로 넘어올 수 있었다. 객체라는 개념이 포인터 다음으로 이해하기 어려웠기 때문에 개인적으로 해결해야 할 과제로서 남아 있었는데, 이 수업에서 이를 해결할 수 있어서 정말 감회가 깊고 여운이 남는다. 비록 파이썬의 방대한 내용을 소화하기는 어려웠고, 실제로 소화를 다 하지 못하고 끝마치지만 개인적으로 큰 배움을 얻을 수 있어서 기쁘다.
